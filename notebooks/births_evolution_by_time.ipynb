# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
# Read the history of births in Spain from 1975 to 2022.
births_history_path = os.path.join(
        os.getcwd(), 
        "..", 
        "data", 
        "raw", 
        "births_from_1975_to_2022.csv"
    )

df_births_history = pd.read_csv(births_history_path)

# %%
df_births_history.set_index("year", inplace=True)

# %%
df_births_history.plot()
# Out:
# <Axes: xlabel='year'>
